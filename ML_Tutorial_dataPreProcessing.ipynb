# %% [markdown]
# <a href="https://colab.research.google.com/github/agiitp/2024H2-IITP-EMBA-MB511/blob/main/ML_Tutorial_dataPreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing libraries
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
"import error"
#pip install

# %%
# import warnings
import warnings
# ignore warnings
warnings.filterwarnings("ignore")

# %%
#path = "/Users/ag/IIT_Patna/Python_code_ML/"
#data = pd.read_csv("/Users/ag/IIT_Patna/Python_code_ML/data2c.csv")
#data = pd.read_csv(path + "data2c.csv")


# read csv (comma separated value) into data
data = pd.read_csv('data2c.csv')
#print(plt.style.available) # look at available plot styles
#plt.style.use('ggplot')
print(data)
print(type(data))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2710096270.py in <cell line: 0>()
#       5
#       6 # read csv (comma separated value) into data
# ----> 7 data = pd.read_csv('data2c.csv')
#       8 #print(plt.style.available) # look at available plot styles
#       9 #plt.style.use('ggplot')
#
# ...

# %%
# to see features and target variable
data.head(8)
# Out:
#    pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
# 5         40.250200            13.921907              25.124950     26.328293
# 6         53.432928            15.864336              37.165934     37.568592
# 7         45.366754            10.755611              29.038349     34.611142
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 7 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt_numeric       310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   class                     310 non-null    object
# dtypes: float64(6), object(1)
# memory usage: 17.1+ KB

# %%
data.describe()
# Out:
#        pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  \
# count        310.000000           310.000000             310.000000
# mean          60.496653            17.542822              51.930930
# std           17.236520            10.008330              18.554064
# min           26.147921            -6.554948              14.000000
# 25%           46.430294            10.667069              37.000000
# 50%           58.691038            16.357689              49.562398
# 75%           72.877696            22.120395              63.000000
# max          129.834041            49.431864             125.742385
#
#        sacral_slope  pelvic_radius  degree_spondylolisthesis
# count    310.000000     310.000000                310.000000
# mean      42.953831     117.920655                 26.296694
# std       13.423102      13.317377                 37.559027
# min       13.366931      70.082575                -11.058179
# ...

# %%
# Out:
#    pelvic_incidence  pelvic_tilt_numeric  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027817            22.552586              39.609117     40.475232
# 1         39.056951            10.060991              25.015378     28.995960
# 2         68.832021            22.218482              50.092194     46.613539
# 3         69.297008            24.652878              44.311238     44.644130
# 4         49.712859             9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis     class
# 0      98.672917                 -0.254400  Abnormal
# 1     114.405425                  4.564259  Abnormal
# 2     105.985135                 -3.530317  Abnormal
# 3     101.868495                 11.211523  Abnormal
# 4     108.168725                  7.918501  Abnormal

# %%
#df = data.loc[:, data.columns != 'class']
# Out:
# (310, 7)

# %%
color_list = ['red' if i=='Abnormal' else 'green' for i in data.loc[:,'class']]
pd.plotting.scatter_matrix(data.loc[:, data.columns != 'class'],
                                       c=color_list,
                                       figsize= [15,15],
                                       diagonal='hist',
                                       alpha=0.5,
                                       s = 200,
                                       marker = '*',
                                       )


plt.show()

# %%
sns.countplot(x="class", data=data)
data.loc[:,'class'].value_counts()
# Out:
# class
# Abnormal    210
# Normal      100
# Name: count, dtype: int64

# %%
import pandas as pd
customer_data = pd.read_excel("/content/sample_data/002-Customer-Information.xlsx")

# %%
customer_data
# Out:
#       Customer-ID  Customer-ZIP         Address Membership-Date
# 0     N0001110038        110038       Najafgarh      2020-05-03
# 1     R0001110015        110015  Rajouri Garden      1993-08-17
# 2     H0001110024        110024       Hauz Khas      2022-09-19
# 3     S0001110012        110012   Sarai Rohilla      2010-12-13
# 4     K0001110007        110007     Kamla Nagar      2008-04-18
# ...           ...           ...             ...             ...
# 4995  R0088110027        110027  Rajouri Garden      2021-07-16
# 4996  S0094110012        110012   Sarai Rohilla      2019-01-05
# 4997  P0094110005        110005       Paharganj      1987-02-14
# 4998  A0109110035        110035    Adarsh Nagar      2007-05-22
# 4999  N0087110039        110039          Narela      2003-03-22
#
# [5000 rows x 4 columns]

# %%
customer_data.rename(columns={'Customer-ID': 'CustomerID', 'Customer-ZIP': 'CustomerZIP', 'Membership-Date': 'MembershipDate'}, inplace=True)
print(customer_data)
# Out:
#        CustomerID  CustomerZIP         Address MembershipDate
# 0     N0001110038       110038       Najafgarh     2020-05-03
# 1     R0001110015       110015  Rajouri Garden     1993-08-17
# 2     H0001110024       110024       Hauz Khas     2022-09-19
# 3     S0001110012       110012   Sarai Rohilla     2010-12-13
# 4     K0001110007       110007     Kamla Nagar     2008-04-18
# ...           ...          ...             ...            ...
# 4995  R0088110027       110027  Rajouri Garden     2021-07-16
# 4996  S0094110012       110012   Sarai Rohilla     2019-01-05
# 4997  P0094110005       110005       Paharganj     1987-02-14
# 4998  A0109110035       110035    Adarsh Nagar     2007-05-22
# 4999  N0087110039       110039          Narela     2003-03-22
#
# [5000 rows x 4 columns]

# %%
# Rename all columns
customer_data.columns = ['CustomerID', 'CustomerZIP', 'Address','MembershipDate']
customer_data
# Out:
#        CustomerID  CustomerZIP         Address MembershipDate
# 0     N0001110038       110038       Najafgarh     2020-05-03
# 1     R0001110015       110015  Rajouri Garden     1993-08-17
# 2     H0001110024       110024       Hauz Khas     2022-09-19
# 3     S0001110012       110012   Sarai Rohilla     2010-12-13
# 4     K0001110007       110007     Kamla Nagar     2008-04-18
# ...           ...          ...             ...            ...
# 4995  R0088110027       110027  Rajouri Garden     2021-07-16
# 4996  S0094110012       110012   Sarai Rohilla     2019-01-05
# 4997  P0094110005       110005       Paharganj     1987-02-14
# 4998  A0109110035       110035    Adarsh Nagar     2007-05-22
# 4999  N0087110039       110039          Narela     2003-03-22
#
# [5000 rows x 4 columns]

# %%
customer_data.isnull( )
# Out:
#       CustomerID  CustomerZIP  Address  MembershipDate
# 0          False        False    False           False
# 1          False        False    False           False
# 2          False        False    False           False
# 3          False        False    False           False
# 4          False        False    False           False
# ...          ...          ...      ...             ...
# 4995       False        False    False           False
# 4996       False        False    False           False
# 4997       False        False    False           False
# 4998       False        False    False           False
# 4999       False        False    False           False
#
# [5000 rows x 4 columns]

# %%
customer_data.isnull().sum()
# Out:
# CustomerID        0
# CustomerZIP       0
# Address           0
# MembershipDate    0
# dtype: int64

# %%
customer_data = customer_data.dropna()
customer_data
# Out:
#        CustomerID  CustomerZIP         Address MembershipDate
# 0     N0001110038       110038       Najafgarh     2020-05-03
# 1     R0001110015       110015  Rajouri Garden     1993-08-17
# 2     H0001110024       110024       Hauz Khas     2022-09-19
# 3     S0001110012       110012   Sarai Rohilla     2010-12-13
# 4     K0001110007       110007     Kamla Nagar     2008-04-18
# ...           ...          ...             ...            ...
# 4995  R0088110027       110027  Rajouri Garden     2021-07-16
# 4996  S0094110012       110012   Sarai Rohilla     2019-01-05
# 4997  P0094110005       110005       Paharganj     1987-02-14
# 4998  A0109110035       110035    Adarsh Nagar     2007-05-22
# 4999  N0087110039       110039          Narela     2003-03-22
#
# [5000 rows x 4 columns]
