# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import regex as re
import pandas as pd

# %%
path = "/Users/ag/IIT_Patna/Git_Hub/2024H2-IITP-EMBA-MB511/Datasets/001-Sales-Data/" 
#cur_path = os.getcwd()
print(path)
# Read the Excel file into a DataFrame
# By default, it reads the first sheet.
customer_data = pd.read_excel(path + "002-Customer-Information.xlsx")
#customer_data.head()
# Out:
# /Users/ag/IIT_Patna/Git_Hub/2024H2-IITP-EMBA-MB511/Datasets/001-Sales-Data/

# %%
# Print the first 5 rows of the DataFrame
print(customer_data.head())
# Out:
#    Customer-ID  Customer-ZIP         Address Membership-Date
# 0  N0001110038        110038       Najafgarh      2020-05-03
# 1  R0001110015        110015  Rajouri Garden      1993-08-17
# 2  H0001110024        110024       Hauz Khas      2022-09-19
# 3  S0001110012        110012   Sarai Rohilla      2010-12-13
# 4  K0001110007        110007     Kamla Nagar      2008-04-18

# %%
# print the columns in the given data
print(list(customer_data.columns))
# Out:
# ['Customer-ID', 'Customer-ZIP', 'Address', 'Membership-Date']

# %%
# print the shape of the given data
print(customer_data.shape)
# Out:
# (5000, 4)

# %%
# print the length of the given data
print(len(customer_data))
# Out:
# 5000

# %%
# print the data types of the given data
print(customer_data.dtypes)
# Out:
# Customer-ID                object
# Customer-ZIP                int64
# Address                    object
# Membership-Date    datetime64[ns]
# dtype: object

# %%
# print the summary statistics of the given data
print(customer_data.describe())
# Out:
#         Customer-ZIP             Membership-Date
# count    5000.000000                        5000
# mean   110025.026200  2012-05-06 08:05:16.800000
# min    110001.000000         1982-01-22 00:00:00
# 25%    110012.000000         2006-08-27 00:00:00
# 50%    110025.000000         2014-03-31 00:00:00
# 75%    110037.000000         2019-11-11 06:00:00
# max    110050.000000         2024-02-15 00:00:00
# std        14.466049                         NaN

# %%
# print the unique values in the given data
print(customer_data.nunique())
# Out:
# Customer-ID        5000
# Customer-ZIP         50
# Address              49
# Membership-Date    3901
# dtype: int64

# %%
# print the missing values in the given data
print(customer_data.isnull().sum())
# Out:
# Customer-ID        0
# Customer-ZIP       0
# Address            0
# Membership-Date    0
# dtype: int64

# %%
# print the data in the given data
print(customer_data)
# Out:
#       Customer-ID  Customer-ZIP         Address Membership-Date
# 0     N0001110038        110038       Najafgarh      2020-05-03
# 1     R0001110015        110015  Rajouri Garden      1993-08-17
# 2     H0001110024        110024       Hauz Khas      2022-09-19
# 3     S0001110012        110012   Sarai Rohilla      2010-12-13
# 4     K0001110007        110007     Kamla Nagar      2008-04-18
# ...           ...           ...             ...             ...
# 4995  R0088110027        110027  Rajouri Garden      2021-07-16
# 4996  S0094110012        110012   Sarai Rohilla      2019-01-05
# 4997  P0094110005        110005       Paharganj      1987-02-14
# 4998  A0109110035        110035    Adarsh Nagar      2007-05-22
# 4999  N0087110039        110039          Narela      2003-03-22
#
# [5000 rows x 4 columns]

# %%
# print the information of the given data
print(customer_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer-ID      5000 non-null   object
#  1   Customer-ZIP     5000 non-null   int64
#  2   Address          5000 non-null   object
#  3   Membership-Date  5000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 156.4+ KB
# None

# %%
#Bar Charts (for categorical data): Represent the frequency or count of different categories.
category_counts = customer_data['Address'].value_counts()
plt.bar(category_counts.index, category_counts.values)
plt.xlabel('Address')
plt.ylabel('Count')
plt.title('Counts of Address Column')
plt.xticks(rotation=45) # Rotate labels if needed
plt.show()
